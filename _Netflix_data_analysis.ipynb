# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Netflix Data Analysis\8. Netflix Dataset.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7789, step=1)

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.size
# Out:
# 85679

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Task 1 is there any duplicate record in this dataset , if yes then remove the duplicate records ??

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Task 2 is there is any null value in column ?? show with heat map

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Q1 for 'House of cards' , what is the show id and who is the director of this show ??

# %%
data[data['Title'] == 'House of Cards'] # or we can use data[data['Title'].isin(['House of Cards'])] or data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q2 in which year highest number of tv shows and movies were released ?? show with bar graph

# %%
data['Category'].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
 data['Date_N'] = pd.to_datetime(data['Release_Date'], errors='coerce')  # formation of a new column

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# ### Q3 how many movies and tv shows in this dataset ?? show with the bar graph

# %%
category_count = data.groupby('Category')['Category'].count()

# %%
sns.countplot(data['Category']) # or we can use category_count.plot(kind = 'bar')
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %% [markdown]
# ### Q4 show all the movies which are released in year 2000

# %%
data[ (data['Category'] == 'Movie')  & (data['Date_N'].dt.year == 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N]
# Index: []

# %% [markdown]
# ### Q5 show only the titles of all the tv shows that were relesed in india only ??

# %%
data[ (data['Category'] == 'TV Show')  & (data['Country'] == 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q6 Show top 10 directors , who gave the highest number of tv shows and movies to netflix ??

# %%
data['Director'].value_counts().sort_values(ascending = False).head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Shannon Hartman            8
# Name: count, dtype: int64

# %% [markdown]
# ### Q7 show all the records where 'category is movie and Type is comedies' or country is united kingdom

# %%
data[ ((data['Category'] == 'Movie')  & (data['Type'] == 'Comedies')) | (data['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q8 in how many movies/Tv shows , Tom cruise was cast ??

# %%
data[data['Cast'] == 'Tom Cruise'] # str.contains() cannot work on null values so we have remove null values
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N]
# Index: []

# %%
data_new = data.dropna() # it will delete all the rows which have missing values and we stored it in a new data frame

# %%
data_new.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# Date_N          0
# dtype: int64

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N
# 3860  Through chance, human action, past history and... 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %% [markdown]
# ### Q9 what are the different ratings defined by netflix??

# %%
data_new['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Q9.1 how many movies got the TY-14 rating, in canada??

# %%
data[(data['Category'] == 'Movie')  & (data['Rating'] == 'TV-14') & (data['Country'] == 'Canada')].shape
# Out:
# (11, 12)

# %% [markdown]
# #### Q9.2 How many TV shows got the R rating after year 2018??

# %%
data[(data['Category'] == 'TV Show')  & (data['Rating'] == 'R') & (data['Date_N'].dt.year > 2018)].shape
# Out:
# (1, 12)

# %% [markdown]
# ### Q10 what is the maximum duration of tvshow/movie on netflix ???

# %%
data.Duration.dtypes # duration has data type is object so we have to convert it in numeric form first ten find maximum duration
# Out:
# dtype('O')

# %%
data[['Minute','unit']] = data['Duration'].str.split(' ',expand = True) # here in split function we have to pass separator from where we have to separate the column into two different column

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N Minute  \
# ...

# %%
data['Minute'].max()
# Out:
# '99'

# %% [markdown]
# ### Q11 which individual country has the highest number of tv shows ??

# %%
data_tvshow = data[data['Category'] ==  'TV Show']

# %%
data_tvshow['Country'].value_counts()
# Out:
# Country
# United States                                    705
# United Kingdom                                   204
# Japan                                            157
# South Korea                                      147
# India                                             71
#                                                 ...
# United Kingdom, Ireland, United States             1
# United Kingdom, Spain                              1
# Italy, United States                               1
# Japan, Canada                                      1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# ### Q12 How can we sort this data by year??

# %%
data['Year'] = data['Date_N'].dt.year

# %%
 data.sort_values(by = 'Year',ascending = False)
# Out:
#      Show_Id Category                       Title  \
# 601     s602    Movie             Asphalt Burning
# 5060   s5060    Movie                Radium Girls
# 980     s981  TV Show                Bling Empire
# 3237   s3238    Movie               Julie & Julia
# 5305   s5305  TV Show                 Running Man
# ...      ...      ...                         ...
# 6952   s6951  TV Show                  The Tudors
# 6998   s6997  TV Show               The West Wing
# 7448   s7447  TV Show                     Vroomiz
# 7524   s7523  TV Show  Weird Wonders of the World
# 7655   s7654  TV Show           Women Behind Bars
#
#                               Director  \
# 601                     Hallvard Bræin
# 5060  Lydia Dean Pilcher, Ginny Mohler
# 980                                NaN
# 3237                       Nora Ephron
# 5305                               NaN
# ...                                ...
# 6952                               NaN
# ...

# %% [markdown]
# ### Q13 Find all instances where :
# #### Category is movie and type is dramas
# #### or
# #### category is tv show and type is kids tv

# %%
data[(data['Category'] == 'Movie') & (data['Type'] == 'Dramas') | (data['Category'] == 'TV Show') & (data['Type'] == "Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
